# %%
import pandas as pd
http_request_df = pd.read_csv("processed_urls.csv")

# %%
from pycaret.classification import *
from sklearn.model_selection import train_test_split

# %%
train_set, test_set = train_test_split(http_request_df.loc[:8000,:])

# %%
clu1 = setup(data = train_set, target='type', \
             numeric_features=['unicode', 'inequality', 'pipe', 'semicolon', 'curlybrace', 'caret', 'consecutive_num', 'hyphen', 'underscore'])
# Out:
# <style  type="text/css" >
# #T_7e220_row44_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_7e220_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7e220_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_7e220_row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_7e220_row0_col1" class="data row0 col1" >2719</td>
#             </tr>
#             <tr>
#                         <th id="T_7e220_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_7e220_row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_7e220_row1_col1" class="data row1 col1" >type</td>
#             </tr>
#             <tr>
#                         <th id="T_7e220_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_7e220_row2_col0" class="data row2 col0" >Target Type</td>
#                         <td id="T_7e220_row2_col1" class="data row2 col1" >Multiclass</td>
#             </tr>
#             <tr>
#                         <th id="T_7e220_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_7e220_row3_col0" class="data row3 col0" >Label Encoded</td>
#                         <td id="T_7e220_row3_col1" class="data row3 col1" >benign: 0, defacement: 1, malware: 2, phishing: 3</td>
#             </tr>
#             <tr>
#                         <th id="T_7e220_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_7e220_row4_col0" class="data row4 col0" >Original Data</td>
#                         <td id="T_7e220_row4_col1" class="data row4 col1" >(6000, 11)</td>
#             </tr>
#             <tr>
#                         <th id="T_7e220_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_7e220_row5_col0" class="data row5 col0" >Missing Values</td>
#                         <td id="T_7e220_row5_col1" class="data row5 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_7e220_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_7e220_row6_col0" class="data row6 col0" >Numeric Features</td>
#                         <td id="T_7e220_row6_col1" class="data row6 col1" >9</td>
#             </tr>
#             <tr>
#                         <th id="T_7e220_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_7e220_row7_col0" class="data row7 col0" >Categorical Features</td>
#                         <td id="T_7e220_row7_col1" class="data row7 col1" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_7e220_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_7e220_row8_col0" class="data row8 col0" >Ordinal Features</td>
#                         <td id="T_7e220_row8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_7e220_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_7e220_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#                         <td id="T_7e220_row9_col1" class="data row9 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_7e220_level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_7e220_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#                         <td id="T_7e220_row10_col1" class="data row10 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_7e220_level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_7e220_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_7e220_row11_col1" class="data row11 col1" >(4199, 4201)</td>
#             </tr>
#             <tr>
#                         <th id="T_7e220_level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_7e220_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_7e220_row12_col1" class="data row12 col1" >(1801, 4201)</td>
#             </tr>
#             <tr>
#                         <th id="T_7e220_level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_7e220_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#                         <td id="T_7e220_row13_col1" class="data row13 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_7e220_level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_7e220_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#                         <td id="T_7e220_row14_col1" class="data row14 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_7e220_level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_7e220_row15_col0" class="data row15 col0" >Fold Generator</td>
#                         <td id="T_7e220_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#             </tr>
#             <tr>
#                         <th id="T_7e220_level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_7e220_row16_col0" class="data row16 col0" >Fold Number</td>
#                         <td id="T_7e220_row16_col1" class="data row16 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_7e220_level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_7e220_row17_col0" class="data row17 col0" >CPU Jobs</td>
#                         <td id="T_7e220_row17_col1" class="data row17 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_7e220_level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_7e220_row18_col0" class="data row18 col0" >Use GPU</td>
#                         <td id="T_7e220_row18_col1" class="data row18 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_7e220_level0_row19" class="row_heading level0 row19" >19</th>
#                         <td id="T_7e220_row19_col0" class="data row19 col0" >Log Experiment</td>
#                         <td id="T_7e220_row19_col1" class="data row19 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_7e220_level0_row20" class="row_heading level0 row20" >20</th>
#                         <td id="T_7e220_row20_col0" class="data row20 col0" >Experiment Name</td>
#                         <td id="T_7e220_row20_col1" class="data row20 col1" >clf-default-name</td>
#             </tr>
#             <tr>
#                         <th id="T_7e220_level0_row21" class="row_heading level0 row21" >21</th>
#                         <td id="T_7e220_row21_col0" class="data row21 col0" >USI</td>
#                         <td id="T_7e220_row21_col1" class="data row21 col1" >f700</td>
#             </tr>
#             <tr>
#                         <th id="T_7e220_level0_row22" class="row_heading level0 row22" >22</th>
#                         <td id="T_7e220_row22_col0" class="data row22 col0" >Imputation Type</td>
#                         <td id="T_7e220_row22_col1" class="data row22 col1" >simple</td>
#             </tr>
#             <tr>
#                         <th id="T_7e220_level0_row23" class="row_heading level0 row23" >23</th>
#                         <td id="T_7e220_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#                         <td id="T_7e220_row23_col1" class="data row23 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_7e220_level

# %%
best_model = compare_models()
# Out:
# <style  type="text/css" >
#     #T_6a811_ th {
#           text-align: left;
#     }#T_6a811_row0_col0,#T_6a811_row0_col2,#T_6a811_row0_col4,#T_6a811_row1_col0,#T_6a811_row1_col1,#T_6a811_row1_col2,#T_6a811_row1_col3,#T_6a811_row1_col4,#T_6a811_row1_col5,#T_6a811_row1_col6,#T_6a811_row1_col7,#T_6a811_row2_col0,#T_6a811_row2_col1,#T_6a811_row2_col3,#T_6a811_row2_col4,#T_6a811_row2_col5,#T_6a811_row2_col6,#T_6a811_row2_col7,#T_6a811_row3_col0,#T_6a811_row3_col1,#T_6a811_row3_col2,#T_6a811_row3_col3,#T_6a811_row3_col5,#T_6a811_row3_col6,#T_6a811_row3_col7,#T_6a811_row4_col0,#T_6a811_row4_col1,#T_6a811_row4_col2,#T_6a811_row4_col3,#T_6a811_row4_col4,#T_6a811_row4_col5,#T_6a811_row4_col6,#T_6a811_row4_col7,#T_6a811_row5_col0,#T_6a811_row5_col1,#T_6a811_row5_col2,#T_6a811_row5_col3,#T_6a811_row5_col4,#T_6a811_row5_col5,#T_6a811_row5_col6,#T_6a811_row5_col7,#T_6a811_row6_col0,#T_6a811_row6_col1,#T_6a811_row6_col2,#T_6a811_row6_col3,#T_6a811_row6_col4,#T_6a811_row6_col5,#T_6a811_row6_col6,#T_6a811_row6_col7,#T_6a811_row7_col0,#T_6a811_row7_col1,#T_6a811_row7_col2,#T_6a811_row7_col3,#T_6a811_row7_col4,#T_6a811_row7_col5,#T_6a811_row7_col6,#T_6a811_row7_col7,#T_6a811_row8_col0,#T_6a811_row8_col1,#T_6a811_row8_col2,#T_6a811_row8_col3,#T_6a811_row8_col4,#T_6a811_row8_col5,#T_6a811_row8_col6,#T_6a811_row8_col7,#T_6a811_row9_col0,#T_6a811_row9_col1,#T_6a811_row9_col2,#T_6a811_row9_col3,#T_6a811_row9_col4,#T_6a811_row9_col5,#T_6a811_row9_col6,#T_6a811_row9_col7,#T_6a811_row10_col0,#T_6a811_row10_col1,#T_6a811_row10_col2,#T_6a811_row10_col3,#T_6a811_row10_col4,#T_6a811_row10_col5,#T_6a811_row10_col6,#T_6a811_row10_col7,#T_6a811_row11_col0,#T_6a811_row11_col1,#T_6a811_row11_col2,#T_6a811_row11_col3,#T_6a811_row11_col4,#T_6a811_row11_col5,#T_6a811_row11_col6,#T_6a811_row11_col7,#T_6a811_row12_col0,#T_6a811_row12_col1,#T_6a811_row12_col2,#T_6a811_row12_col3,#T_6a811_row12_col4,#T_6a811_row12_col5,#T_6a811_row12_col6,#T_6a811_row12_col7,#T_6a811_row13_col0,#T_6a811_row13_col1,#T_6a811_row13_col2,#T_6a811_row13_col3,#T_6a811_row13_col4,#T_6a811_row13_col5,#T_6a811_row13_col6,#T_6a811_row13_col7{
#             text-align:  left;
#             text-align:  left;
#         }#T_6a811_row0_col1,#T_6a811_row0_col3,#T_6a811_row0_col5,#T_6a811_row0_col6,#T_6a811_row0_col7,#T_6a811_row2_col2,#T_6a811_row3_col4{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_6a811_row0_col8,#T_6a811_row1_col8,#T_6a811_row2_col8,#T_6a811_row3_col8,#T_6a811_row4_col8,#T_6a811_row5_col8,#T_6a811_row6_col8,#T_6a811_row7_col8,#T_6a811_row8_col8,#T_6a811_row10_col8,#T_6a811_row11_col8,#T_6a811_row12_col8,#T_6a811_row13_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }#T_6a811_row9_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#             background-color:  lightgrey;
#         }</style><table id="T_6a811_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>        <th class="col_heading level0 col8" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6a811_level0_row0" class="row_heading level0 row0" >dt</th>
#                         <td id="T_6a811_row0_col0" class="data row0 col0" >Decision Tree Classifier</td>
#                         <td id="T_6a811_row0_col1" class="data row0 col1" >0.7861</td>
#                         <td id="T_6a811_row0_col2" class="data row0 col2" >0.6442</td>
#                         <td id="T_6a811_row0_col3" class="data row0 col3" >0.3820</td>
#                         <td id="T_6a811_row0_col4" class="data row0 col4" >0.7350</td>
#                         <td id="T_6a811_row0_col5" class="data row0 col5" >0.7404</td>
#                         <td id="T_6a811_row0_col6" class="data row0 col6" >0.3624</td>
#                         <td id="T_6a811_row0_col7" class="data row0 col7" >0.4081</td>
#                         <td id="T_6a811_row0_col8" class="data row0 col8" >0.3770</td>
#             </tr>
#             <tr>
#                         <th id="T_6a811_level0_row1" class="row_heading level0 row1" >rf</th>
#                         <td id="T_6a811_row1_col0" class="data row1 col0" >Random Forest Classifier</td>
#                         <td id="T_6a811_row1_col1" class="data row1 col1" >0.7854</td>
#                         <td id="T_6a811_row1_col2" class="data row1 col2" >0.7280</td>
#                         <td id="T_6a811_row1_col3" class="data row1 col3" >0.3634</td>
#                         <td id="T_6a811_row1_col4" class="data row1 col4" >0.7437</td>
#                         <td id="T_6a811_row1_col5" class="data row1 col5" >0.7322</td>
#                         <td id="T_6a811_row1_col6" class="data row1 col6" >0.3277</td>
#                         <td id="T_6a811_row1_col7" class="data row1 col7" >0.3991</td>
#                         <td id="T_6a811_row1_col8" class="data row1 col8" >0.6970</td>
#             </tr>
#             <tr>
#                         <th id="T_6a811_level0_row2" class="row_heading level0 row2" >gbc</th>
#                         <td id="T_6a811_row2_col0" class="data row2 col0" >Gradient Boosting Classifier</td>
#                         <td id="T_6a811_row2_col1" class="data row2 col1" >0.7823</td>
#                         <td id="T_6a811_row2_col2" class="data row2 col2" >0.7813</td>
#                         <td id="T_6a811_row2_col3" class="data row2 col3" >0.3438</td>
#                         <td id="T_6a811_row2_col4" class="data row2 col4" >0.7253</td>
#                         <td id="T_6a811_row2_col5" class="data row2 col5" >0.7266</td>
#                         <td id="T_6a811_row2_col6" class="data row2 col6" >0.3138</td>
#                         <td id="T_6a811_row2_col7" class="data row2 col7" >0.3866</td>
#                         <td id="T_6a811_row2_col8" class="data row2 col8" >6.5600</td>
#             </tr>
#             <tr>
#                         <th id="T_6a811_level0_row3" class="row_heading level0 row3" >et</th>
#                         <td id="T_6a811_row3_col0" class="data row3 col0" >Extra Trees Classifier</td>
#                         <td id="T_6a811_row3_col1" class="data row3 col1" >0.7811</td>
#                         <td id="T_6a811_row3_col2" class="data row3 col2" >0.7182</td>
#                         <td id="T_6a811_row3_col3" class="data row3 col3" >0.3548</td>
#                         <td id="T_6a811_row3_col4" class="data row3 col4" >0.7571</td>
#                         <td id="T_6a811_row3_col5" class="data row3 col5" >0.7242</td>
#                         <td id="T_6a811_row3_col6" class="data row3 col6" >0.2993</td>
#                         <td id="T_6a811_row3_col7" class="data row3 col7" >0.3841</td>
#                         <td id="T_6a811_row3_col8" class="data row3 col8" >0.9150</td>
#             </tr>
#             <tr>
#                         <th id="T_6a811_level0_row4" class="row_heading level0 row4" >lightgbm</th>
#                         <td id="T_6a811_row4_col0" class="data row4 col0" >Light Gradient Boosting Machine</td>
#                         <td id="T_6a811_row4_col1" class="data row4 col1" >0.7783</td>
#                         <td id="T_6a811_row4_col2" class="data row4 col2" >0.7756</td>
#                         <td id="T_6a811_row4_col3" class="data row4 col3" >0.3555</td>
#                         <td id="T_6a811_row4_col4" class="data row4 col4" >0.7092</td>
#                         <td id="T_6a811_row4_col5" class="data row4 col5" >0.7309</td>
#                         <td id="T_6a811_row4_co

# %%
evaluate_model(best_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %%
results = predict_model(best_model, test_set)
# Out:
# <style  type="text/css" >
# </style><table id="T_77f5a_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_77f5a_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_77f5a_row0_col0" class="data row0 col0" >Decision Tree Classifier</td>
#                         <td id="T_77f5a_row0_col1" class="data row0 col1" >0.0000</td>
#                         <td id="T_77f5a_row0_col2" class="data row0 col2" >0.6630</td>
#                         <td id="T_77f5a_row0_col3" class="data row0 col3" >0</td>
#                         <td id="T_77f5a_row0_col4" class="data row0 col4" >0</td>
#                         <td id="T_77f5a_row0_col5" class="data row0 col5" >0</td>
#                         <td id="T_77f5a_row0_col6" class="data row0 col6" >0</td>
#                         <td id="T_77f5a_row0_col7" class="data row0 col7" >0</td>
#             </tr>
#     </tbody></table>

# %%
results
# Out:
#                                                     url        type  unicode  \
# 3454  http://antenassaojose.com.br/site/index.php?op...  defacement        0
# 7084  http://www.originalvolunteers.co.uk/extra-info...  defacement        0
# 6413     dizzygillespie.org/artistpages/faddisframe.htm      benign        0
# 2156      rootsweb.ancestry.com/~tngenny1/crocket2.html      benign        0
# 2397       ethixmerch.com/blog/fair-trade-usa-vs-europe      benign        0
# ...                                                 ...         ...      ...
# 7460           linkedin.com/pub/alain-marcotte/4/60/a98      benign        0
# 3512  http://plarium.com/en/strategy-games/stormfall...      benign        0
# 5666  healthgrades.com/physician/dr-richard-tallman-...      benign        0
# 1119                     thenhf.com/article.php?id=2113      benign        0
# 1423  m.yahoo.com/w/sports/home/experts/article?offs...      benign        0
#
#       inequality  pipe  semicolon  curlybrace  caret  consecutive_num  hyphen  \
# 3454           0     0          0           0      0                5       0
# 7084           0     0          0           0      0                0       2
# 6413           0     0          0           0      0                0       0
# 2156           0     0          0           0      0                1       0
# 2397           0     0          0           0      0                0       4
# ...          ...   ...        ...         ...    ...              ...     ...
# 7460           0     0          0           0      0                2       1
# 3512           0     0          0           0      0                0       7
# 5666           0     0          0           0      0                2       3
# 1119           0     0          0           0      0                4       0
# 1423           0     0          0           0      0               10       2
#
#       underscore       Label  Score
# 3454           1      benign    1.0
# 7084           0      benign    1.0
# 6413           0      benign    1.0
# 2156           0      benign    1.0
# 2397           0      benign    1.0
# ...          ...         ...    ...
# 7460           0      benign    1.0
# 3512           0      benign    1.0
# 5666           0  defacement    1.0
# 1119           0      benign    1.0
# 1423           5      benign    1.0
#
# [2001 rows x 13 columns]

# %%
correct_pred_count = 0
for index in range(len(results['Label'])):
    if results['Label'].iloc[index] == results['type'].iloc[index]:
        correct_pred_count += 1

print(correct_pred_count / len(results['Label'])) # About 79.86% prediction accuracy using a random forest classifer
# Out:
# 0.7986006996501749

# %%
save_model(best_model, 'basic_DT_url_classifier')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=[],
#                                        ml_usecase='classification',
#                                        numerical_features=['unicode',
#                                                            'inequality', 'pipe',
#                                                            'semicolon',
#                                                            'curlybrace', 'caret',
#                                                            'consecutive_num',
#                                                            'hyphen',
#                                                            'underscore'],
#                                        target='type', time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(cate...
#                  ('dfs', 'passthrough'), ('pca', 'passthrough'),
#                  ['trained_model',
#                   DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None,
#                                          criterion='gini', max_depth=None,
#                                          max_features=None, max_leaf_nodes=None,
#                                          min_impurity_decrease=0.0,
#                                          min_impurity_split=None,
#                                          min_samples_leaf=1, min_samples_split=2,
#                                          min_weight_fraction_leaf=0.0,
#                                          presort='deprecated', random_state=5661,
#                                          splitter='best')]],
#           verbose=False),
#  'basic_DT_url_classifier.pkl')

# %%
loaded_model = load_model('basic_DT_url_classifier')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
type(loaded_model)
# Out:
# sklearn.pipeline.Pipeline
